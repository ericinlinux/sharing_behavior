# %%
# Standard libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from random import random
from pprint import pprint
import _pickle as pickle
import math
import time

# %%
# My libraries
import sim_ann as sa
import model

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
results = sa.get_error()

# %%
results[0]
# Out:
# 93.020452637355262

# %%
results[1]
# Out:
# {'arousal': [0.9, 2],
#  'attention_1': [2.8, 2],
#  'attention_2': [0.5, 5],
#  'comment': [0.7, 3],
#  'ff_ent': [1.4, 2],
#  'ff_is': [2.1, 4],
#  'ff_ko': [1.4, 2],
#  'ff_se': [2.8, 2],
#  'ff_si': [1.4, 4],
#  'like': [0.7, 3],
#  'mood': [1.4, 2],
#  'mood_speed': 0.01,
#  'prep_comm': [3.5, 2],
#  'prep_like': [2.8, 2],
#  'prep_share': [2.1, 3],
#  'satisfaction': [1.0, 5],
#  'share': [0.7, 3],
#  'srs_sal': [0.7, 2]}

# %% [markdown]
# # Agent 1

# %%
# Testing arousal
results[8][['arousal', 'satisfaction']].plot(figsize=((14,8)))

# %%
results[8][['satisfaction', 'ff_si', 'nf_si']].plot(figsize=((14,8)))

# %%
results[8][['mood', 'ff_ko', 'ff_ent', 'ff_is', 'ff_si', 'ff_se']].plot(figsize=((14,8)))

# %%
results[8][['attention_1', 'attention_2']].plot(figsize=((14,8)))

# %%
results[8][['prep_share', 'prep_comm', 'prep_like']].plot(figsize=((14,8)))

# %%
fig = plt.figure(figsize=((14,8)))

ax1 = fig.add_subplot(211)
results[2][['mood', 'like', 'share', 'comment']].plot(ax=ax1)

ax2 = fig.add_subplot(212)
results[3][['mood', 'like', 'share', 'comment']].plot(ax=ax2)

# %%
# 8, 9 and 10 (agents 1, 2, 3)

# %%
results[9].columns
# Out:
# Index(['arousal', 'attention_1', 'attention_2', 'comment', 'ff_ent', 'ff_is',
#        'ff_ko', 'ff_se', 'ff_si', 'like', 'mood', 'msg_cat_con', 'msg_cat_edu',
#        'msg_cat_ent', 'msg_cat_new', 'msg_cat_per', 'msg_com', 'msg_med',
#        'msg_qua', 'msg_que', 'msg_rel', 'msg_sal', 'msg_sen', 'nf_ent',
#        'nf_is', 'nf_ko', 'nf_se', 'nf_si', 'prep_comm', 'prep_like',
#        'prep_share', 'pt_cons', 'satisfaction', 'share', 'srs_cat_con',
#        'srs_cat_edu', 'srs_cat_ent', 'srs_cat_new', 'srs_cat_per', 'srs_com',
#        'srs_med', 'srs_qua', 'srs_que', 'srs_rel', 'srs_sal', 'srs_sen',
#        'ss_cat_con', 'ss_cat_edu', 'ss_cat_ent', 'ss_cat_new', 'ss_cat_per',
#        'ss_com', 'ss_med', 'ss_qua', 'ss_que', 'ss_rel', 'ss_sal', 'ss_sen',
#        'ssr_pe_c', 'ssr_pe_l', 'ssr_pe_s'],
#       dtype='object')

# %%
def alogistic(c, tau, sigma):
    return ((1/(1+math.exp(-sigma*(c-tau))))-(1/(1+math.exp(sigma*tau))))*(1+math.exp(-sigma*tau))

# %%
alogistic(-100, -0.5, 2)
