# %%
# Standard libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from random import random
from pprint import pprint

import time

# %%
# My libraries
import sim_ann as sa
import model

# %% [markdown]
# ## Perform simulated annealing.
#
# Change the values for min and max temperature and alpha in the file sim_ann.py.

# %%
t0 = time.time()
parameters, cost_hist, parameters_hist = sa.parameter_tuning()
t1 = time.time()
total = t1-t0
print('Total time spent: ', total)
# Out:
# Temp:  1.0
# {'arousal': [0.3, 4],
#  'attention_1': [2.8, 2],
#  'attention_2': [0.2, 2],
#  'dissatisfaction': [0.2, 2],
#  'ff_ent': [1.4, 2],
#  'ff_is': [2.1, 4],
#  'ff_ko': [1.4, 2],
#  'ff_se': [2.8, 2],
#  'ff_si': [1.4, 4],
#  'mood': [6.3, 2],
#  'mood_speed': 0.5,
#  'prep_comm': [3.5, 2],
#  'prep_like': [2.8, 2],
#  'prep_share': [2.1, 3],
#  'satisfaction': [2.8, 2],
#  'srs_sal': [0.7, 2]}
# 174.362584207
# Temp:  0.8
# {'arousal': [0.3, 4],
#  'attention_1': [2.8, 2],
#  'attention_2': [0.2, 2],
#  'dissatisfaction': [0.2, 2],
#  'ff_ent': [1.4, 2],
#  'ff_is': [2.1, 4],
#  'ff_ko': [1.4, 2],
#  'ff_se': [2.8, 2],
#  'ff_si': [1.4, 4],
#  'mood': [6.3, 2],
#  'mood_speed': 0.5,
#  'prep_comm': [3.5, 2],
#  'prep_like': [2.8, 2],
#  'prep_share': [2.1, 3],
#  'satisfaction': [2.8, 2],
#  'srs_sal': [0.7, 2]}
# 174.362584207
# Temp:  0.6400000000000001
# {'arousal': [0.3, 4],
#  'attention_1': [2.8, 2],
#  'attention_2': [0.2, 2],
#  'dissatisfaction': [0.2, 2],
#  'ff_ent': [1.4, 2],
#  'ff_is': [2.1, 4],
#  'ff_ko': [1.4, 2],
#  'ff_se': [2.8, 2],
#  'ff_si': [1.4, 4],
#  'mood': [6.3, 2],
#  'mood_speed': 0.5,
#  'prep_comm': [3.5, 2],
#  'prep_like': [2.8, 2],
#  'prep_share': [2.1, 3],
#  'satisfaction': [2.8, 2],
#  'srs_sal': [0.7, 2]}
# 174.362584207
# Temp:  0.5120000000000001
# {'arousal': [0.3, 4],
#  'attention_1': [2.8, 2],
#  'attention_2': [0.2, 2],
#  'dissatisfaction': [0.2, 2],
#  'ff_ent': [1.4, 2],
#  'ff_is': [2.1, 4],
#  'ff_ko': [1.4, 2],
#  'ff_se': [2.8, 2],
#  'ff_si': [1.4, 4],
#  'mood': [6.3, 2],
#  'mood_speed': 0.5,
#  'prep_comm': [3.5, 2],
#  'prep_like': [2.8, 2],
#  'prep_share': [2.1, 3],
#  'satisfaction': [2.8, 2],
#  'srs_sal': [0.7, 2]}
# 174.362584207
# Temp:  0.40960000000000013
# {'arousal': [0.3, 4],
#  'attention_1': [2.8, 2],
#  'attention_2': [0.2, 2],
#  'dissatisfaction': [0.2, 2],
#  'ff_ent': [1.4, 2],
#  'ff_is': [2.1, 4],
#  'ff_ko': [1.4, 2],
#  'ff_se': [2.8, 2],
#  'ff_si': [1.4, 4],
#  'mood': [6.3, 2],
#  'mood_speed': 0.5,
#  'prep_comm': [3.5, 2],
#  'prep_like': [2.8, 2],
#  'prep_share': [2.1, 3],
#  'satisfaction': [2.8, 2],
#  'srs_sal': [0.7, 2]}
# 174.362584207
# Temp:  0.32768000000000014
# {'arousal': [0.3, 4],
#  'attention_1': [2.8, 2],
#  'attention_2': [0.2, 2],
#  'dissatisfaction': [0.2, 2],
#  'ff_ent': [1.4, 2],
#  'ff_is': [2.1, 4],
#  'ff_ko': [1.4, 2],
#  'ff_se': [2.8, 2],
#  'ff_si': [1.4, 4],
#  'mood': [6.3, 2],
#  'mood_speed': 0.5,
#  'prep_comm': [3.5, 2],
#  'prep_like': [2.8, 2],
#  'prep_share': [2.1, 3],
#  'satisfaction': [2.8, 2],
#  'srs_sal': [0.7, 2]}
# 174.362584207
# Temp:  0.2621440000000001
# {'arousal': [0.3, 4],
#  'attention_1': [2.8, 2],
#  'attention_2': [0.2, 2],
#  'dissatisfaction': [0.2, 2],
#  'ff_ent': [1.4, 2],
#  'ff_is': [2.1, 4],
#  'ff_ko': [1.4, 2],
#  'ff_se': [2.8, 2],
#  'ff_si': [1.4, 4],
#  'mood': [6.3, 2],
#  'mood_speed': 0.5,
#  'prep_comm': [3.5, 2],
#  'prep_like': [2.8, 2],
#  'prep_share': [2.1, 3],
#  'satisfaction': [2.8, 2],
#  'srs_sal': [0.7, 2]}
# 174.362584207
# Temp:  0.2097152000000001
# {'arousal': [0.3, 4],
#  'attention_1': [2.8, 2],
#  'attention_2': [0.2, 2],
#  'dissatisfaction': [0.2, 2],
#  'ff_ent': [1.4, 2],
#  'ff_is': [2.1, 4],
#  'ff_ko': [1.4, 2],
#  'ff_se': [2.8, 2],
#  'ff_si': [1.4, 4],
#  'mood': [6.3, 2],
#  'mood_speed': 0.5,
#  'prep_comm': [3.5, 2],
#  'prep_like': [2.8, 2],
#  'prep_share': [2.1, 3],
#  'satisfaction': [2.8, 2],
#  'srs_sal': [0.7, 2]}
# 174.362584207
# Temp:  0.1677721600000001
# {'arousal': [0.3, 4],
#  'attention_1': [2.8, 2],
#  'attention_2': [0.2, 2],
#  'dissatisfaction': [0.2, 2],
#  'ff_ent': [1.4, 2],
#  'ff_is': [2.1, 4],
#  'ff_ko': [1.4, 2],
#  'ff_se': [2.8, 2],
#  'ff_si': [1.4, 4],
#  'mood': [6.3, 2],
#  'mood_speed': 0.5,
#  'prep_comm': [3.5, 2],
#  'prep_like': [2.8, 2],
#  'prep_share': [2.1, 3],
#  'satisfaction': [2.8, 2],
#  'srs_sal': [0.7, 2]}
# 174.362584207
# Temp:  0.13421772800000006
# {'arousal': [0.3, 4],
#  'attention_1': [2.8, 2],
#  'attention_2': [0.2, 2],
#  'dissatisfaction': [0.2, 2],
#  'ff_ent': [1.4, 2],
#  'ff_is': [2.1, 4],
#  'ff_ko': [1.4, 2],
#  'ff_se': [2.8, 2],
#  'ff_si': [1.4, 4],
#  'mood': [6.3, 2],
#  'mood_speed': 0.5,
#  'prep_comm': [3.5, 2],
#  'prep_like': [2.8, 2],
#  'prep_share': [2.1, 3],
#  'satisfaction': [2.8, 2],
#  'srs_sal': [0.7, 2]}
# 174.362584207
# Temp:  0.10737418240000006
# {'arousal': [0.3, 4],
#  'attention_1': [2.8, 2],
#  'attention_2': [0.2, 2],
#  'dissatisfaction': [0.2, 2],
#  'ff_ent': [1.4, 2],
#  'ff_is': [2.1, 4],
#  'ff_ko': [1.4, 2],
#  'ff_se': [2.8, 2],
#  'ff_si': [1.4, 4],
#  'mood': [6.3, 2],
#  'mood_speed': 0.5,
#  'prep_comm': [3.5, 2],
#  'prep_like': [2.8, 2],
#  'prep_share': [2.1, 3],
#  'satisfaction': [2.8, 2],
#  'srs_sal': [0.7, 2]}
# 174.362584207
# Temp:  0.08589934592000005
# {'arousal': [0.3, 4],
#  'attention_1': [2.8, 2],
#  'attention_2': [0.2, 2],
#  'dissatisfaction': [0.2, 2],
#  'ff_ent': [1.4, 2],
#  'ff_is': [2.1, 4],
#  'ff_ko': [1.4, 2],
#  'ff_se': [2.8, 2],
#  'ff_si': [1.4, 4],
#  'mood': [6.3, 2],
#  'mood_speed': 0.5,
#  'prep_comm': [3.5, 2],
#  'prep_like': [2.8, 2],
#  'prep_share': [2.1, 3],
#  'satisfaction': [2.8, 2],
#  'srs_sal': [0.7, 2]}
# 174.362584207
# Temp:  0.06871947673600004
# {'arousal': [0.3, 4],
#  'attention_1': [2.8, 2],
#  'attention_2': [0.2, 2],
#  'dissatisfaction': [0.2, 2],
#  'ff_ent': [1.4, 2],
#  'ff_is': [2.1, 4],
#  'ff_ko': [1.4, 2],
#  'ff_se': [2.8, 2],
#  'ff_si': [1.4, 4],
#  'mood': [6.3, 2],
#  'mood_speed': 0.5,
#  'prep_comm': [3.5, 2],
#  'prep_like': [2.8, 2],
#  'prep_share': [2.1, 3],
#  'satisfaction': [2.8, 2],
#  'srs_sal': [0.7, 2]}
# 174.362584207
# Temp:  0.054975581388800036
# {'arousal': [0.3, 4],
#  'attention_1': [2.8, 2],
#  'attention_2': [0.2, 2],
#  'dissatisfaction': [0.2, 2],
#  'ff_ent': [1.4, 2],
#  'ff_is': [2.1, 4],
#  'ff_ko': [1.4, 2],
#  'ff_se': [2.8, 2],
#  'ff_si': [1.4, 4],
#  'mood': [6.3, 2],
#  'mood_speed': 0.5,
#  'prep_comm': [3.5, 2],
#  'prep_like': [2.8, 2],
#  'prep_share': [2.1, 3],
#  'satisfaction': [2.8, 2],
#  'srs_sal': [0.7, 2]}
# 174.362584207
# Temp:  0.043980465111040035
# {'arousal': [0.3, 4],
#  'attention_1': [2.8, 2],
#  'attention_2': [0.2, 2],
#  'dissatisfaction': [0.2, 2],
#  'ff_ent': [1.4, 2],
#  'ff_is': [2.1, 4],
#  'ff_ko': [1.4, 2],
#  'ff_se': [2.8, 2],
#  'ff_si': [1.4, 4],
#  'mood': [6.3, 2],
#  'mood_speed': 0.5,
#  'prep_comm': [3.5, 2],
#  'prep_like': [2.8, 2],
#  'prep_share': [2.1, 3],
#  'satisfaction': [2.8, 2],
#  'srs_sal': [0.7, 2]}
# 174.362584207
# Temp:  0.03518437208883203
# {'arousal': [0.3, 4],
#  'attention_1': [2.8, 2],
#  'attention_2': [0.2, 2],
#  'dissatisfaction': [0.2, 2],
#  'ff_ent': [1.4, 2],
#  'ff_is': [2.1, 4],
#  'ff_ko': [1.4, 2],
#  'ff_se': [2.8, 2],
#  'ff_si': [1.4, 4],
#  'mood': [6.3, 2],
#  'mood_speed': 0.5,
#  'prep_comm': [3.5, 2],
#  'prep_like': [2.8, 2],
#  'prep_share': [2.1, 3],
#  'satisfaction': [2.8, 2],
#  'srs_sal': [0.7, 2]}
# 174.362584207
# Temp:  0.028147497671065627
# {'arousal': [0.3, 4],
#  'attention_1': [2.8, 2],
#  'attention_2': [0.2, 2],
#  'dissatisfaction': [0.2, 2],
#  'ff_ent': [1.4, 2],
#  'ff_is': [2.1, 4],
#  'ff_ko': [1.4, 2],
#  'ff_se': [2.8, 2],
#  'ff_si': [1.4, 4],
#  'mood': [6.3, 2],
#  'mood_speed': 0.5,
#  'prep_comm': [3.5, 2],
#  'prep_like': [2.8, 2],
#  'prep_share': [2.1, 3],
#  'satisfaction': [2.8, 2],
#  'srs_sal': [0.7, 2]}
# 174.362584207
# Temp:  0.022517998136852502
# {'arousal': [0.3, 4],
#  'attention_1': [2.8, 2],
#  'attention_2': [0.2, 2],
#  'dissatisfaction': [0.2, 2],
#  'ff_ent': [1.4, 2],
#  'ff_is': [2.1, 4],
#  'ff_ko': [1.4, 2],
#  'ff_se': [2.8, 2],
#  'ff_si': [1.4, 4],
#  'mood': [6.3, 2],
#  'mood_speed': 0.5,
#  'prep_comm': [3.5, 2],
#  'prep_like': [2.8, 2],
#  'prep_share': [2.1, 3],
#  'satisfaction': [2.8, 2],
#  'srs_sal': [0.7, 2]}
# 174.362584207
# Temp:  0.018014398509482003
# {'arousal': [0.3, 4],
#  'attention_1': [2.8, 2],
#  'attention_2': [0.2, 2],
#  'dissatisfaction': [0.2, 2],
#  'ff_ent': [1.4, 2],
#  'ff_is': [2.1, 4],
#  'ff_ko': [1.4, 2],
#  'ff_se': [2.8, 2],
#  'ff_si': [1.4, 4],
#  'mood': [6.3, 2],
#  'mood_speed': 0.5,
#  'prep_comm': [3.5, 2],
#  'prep_like': [2.8, 2],
#  'prep_share': [2.1, 3],
#  'satisfaction': [2.8, 2],
#  'srs_sal': [0.7, 2]}
# 174.362584207
# Temp:  0.014411518807585602
# {'arousal': [0.3, 4],
#  'attention_1': [2.8, 2],
#  'attention_2': [0.2, 2],
#  'dissatisfaction': [0.2, 2],
#  'ff_ent': [1.4, 2],
#  'ff_is': [2.1, 4],
#  'ff_ko': [1.4, 2],
#  'ff_se': [2.8, 2],
#  'ff_si': [1.4, 4],
#  'mood': [6.3, 2],
#  'mood_speed': 0.5,
#  'prep_comm': [3.5, 2],
#  'prep_like': [2.8, 2],
#  'prep_share': [2.1, 3],
#  'satisfaction': [2.8, 2],
#  'srs_sal': [0.7, 2]}
# 174.362584207
# Temp:  0.011529215046068483
# {'arousal': [0.3, 4],
#  'attention_1': [2.8, 2],
#  'attention_2': [0.2, 2],
#  'dissatisfaction': [0.2, 2],
#  'ff_ent': [1.4, 2],
#  'ff_is': [2.1, 4],
#  'ff_ko': [1.4, 2],
#  'ff_se': [2.8, 2],
#  'ff_si': [1.4, 4],
#  'mood': [6.3, 2],
#  'mood_speed': 0.5,
#  'prep_comm': [3.5, 2],
#  'prep_like': [2.8, 2],
#  'prep_share': [2.1, 3],
#  'satisfaction': [2.8, 2],
#  'srs_sal': [0.7, 2]}
# 174.362584207
# Total time spent:  385.0526759624481

# %% [markdown]
# ## Process results

# %%
#steepness values from 0.5 (for four arrows), 0.7 (for three arrows),  1 (for two arrows) to 2.5 (for 1 arrow)
a = parameters_hist[-1]

# %%
a
# Out:
# {'arousal': [0.3, 4],
#  'attention_1': [2.8, 2],
#  'attention_2': [0.2, 2],
#  'dissatisfaction': [0.2, 2],
#  'ff_ent': [1.4, 2],
#  'ff_is': [2.1, 4],
#  'ff_ko': [1.4, 2],
#  'ff_se': [2.8, 2],
#  'ff_si': [1.4, 4],
#  'mood': [6.3, 2],
#  'mood_speed': 0.5,
#  'prep_comm': [3.5, 2],
#  'prep_like': [2.8, 2],
#  'prep_share': [2.1, 3],
#  'satisfaction': [2.8, 2],
#  'srs_sal': [0.7, 2]}

# %%
new_cost = sa.get_error(a)

# %%
new_cost
# Out:
# (174.36258420706582,
#  {'arousal': [0.3, 4],
#   'attention_1': [2.8, 2],
#   'attention_2': [0.2, 2],
#   'dissatisfaction': [0.2, 2],
#   'ff_ent': [1.4, 2],
#   'ff_is': [2.1, 4],
#   'ff_ko': [1.4, 2],
#   'ff_se': [2.8, 2],
#   'ff_si': [1.4, 4],
#   'mood': [6.3, 2],
#   'mood_speed': 0.5,
#   'prep_comm': [3.5, 2],
#   'prep_like': [2.8, 2],
#   'prep_share': [2.1, 3],
#   'satisfaction': [2.8, 2],
#   'srs_sal': [0.7, 2]},
#                 mood          like         share       comment
#  19     9.536854e-07  2.167511e-13  2.724014e-13  5.418440e-14
#  39     1.819010e-12  2.335933e-26  2.935679e-26  6.516263e-05
#  59     3.469487e-18  1.853603e-39  2.329511e-39  1.829142e-02
#  79     6.617522e-24  1.301547e-52  1.635716e-52  1.614425e-03
#  99     1.262192e-29  8.552563e-66  1.074841e-65  3.320566e-13
#  119    2.407440e-35  7.474968e-04  5.853473e-04  2.316567e-02
#  139    4.591828e-41  3.184218e-13  2.493487e-13  6.489869e-03
#  159    8.758217e-47  3.621417e-26  2.835847e-26  3.954626e-02
#  179    7.210669e-09  2.922059e-39  2.288196e-39  7.040610e-04
#  199    1.102346e-13  1.383981e-03  1.124869e-03  7.409669e-03
#  219    2.102559e-19  6.110442e-04  4.744896e-04  2.003847e-02
#  239    4.010313e-25  8.412233e-06  6.281326e-06  2.086526e-02
#  259    7.649064e-31  3.583497e-15  2.675759e-15  3.641089e-03
#  279    1.458943e-36  4.075517e-28  3.043145e-28  1.774345e-03
#  299    1.170322e-08  3.288465e-41  2.455462e-41  1.895725e-02
#  319    9.099385e-09  1.114618e-03  8.921137e-04  6.380209e-03
#  339    1.388484e-13  1.833981e-12  1.422045e-12  4.525094e-03
#  359    2.648323e-19  2.176324e-25  1.686337e-25  8.463965e-03
#  379    5.051275e-25  1.777920e-38  1.377364e-38  1.168871e-04
#  1899  4.940656e-324   0.000000e+00   0.000000e+00   4.437529e-14
#  1919  4.940656e-324   0.000000e+00   0.000000e+00   4.889113e-27
#  1939  4.940656e-324   0.000000e+00   0.000000e+00   3.906828e-40
#  1959  4.940656e-324   0.000000e+00   0.000000e+00   2.752697e-53
#  1979  4.940656e-324   0.000000e+00   0.000000e+00   1.812511e-66
#  1999  4.940656e-324   0.000000e+00   0.000000e+00   1.143900e-79
#
#  [100 rows x 4 columns],
#        mood  like  comment  share
#  time
#  19     0.5     0        0      0
#  39     0.5     0        0      0
#  59     0.5     0        0      0
#  79     0.5     0        0      0
#  99     0.5     0        0      0
#  119    0.5     0        0      0
#  139    0.5     0        0      0
#  159    0.5     0        0      0
#  179    0.5     0        0      0
#  199    0.5     0        0      0
#  219    0.5     0        0      0
#  239    0.4     0        0      0
#  259    0.4     0        0      0
#  279    0.4     0        0      0
#  299    0.4     0        0      0
#  319    0.4     0        0      0
#  339    0.4     0        0      0
#  359    0.4     0        0      0
#  379    0.4     0        0      0
#  399    0.4     0        0      0
#  419    0.4     0        0      0
#  439    0.5     0        1      0
#  459    0.5     0        0      0
#  479    0.5     1        0      0
#  499    0.5     0        0      0
#  519    0.5     0        0      0
#  539    0.5     0        0      0
#  559    0.5     0        0      0
#  579    0.5     0        0      0
#  599    0.5     0        0      0
#  ...    ...   ...      ...    ...
#  1419   0.6     0        0      0
#  1439   0.6     0        0      0
#  1459   0.6     0        0      0
#  1479   0.6     0        0      0
#  1499   0.6     0        0      0
#  1519   0.6     0        0      0
#  1539   0.6     0        0      0
#  1559   0.6     0        0      0
#  1579   0.7     1        0      1
#  1599   0.7     0        0      0
#  1619   0.7     0        0      0
#  1639   0.7     0        0      0
#  1659   0.7     0        0      0
#  1679   0.8     1        0      1
#  1699   0.8     0        1      0
#  1719   0.8     0        0      0
#  1739   0.8     0        0      0
#  1759   0.8     0        0      0
#  1779   0.8     0        0      0
#  1799   0.8     0        0      0
#  1819   0.8     0        0      0
#  1839   0.7     0        0      0
#  1859   0.7     0        0      0
#  1879   0.7     0        0      0
#  1899   0.7     0        0      0
#  1919   0.7     0        0      0
#  1939   0.7     0        0      0
#  1959   0.7     0        0      0
#  1979   0.7     0        0      0
#  1999   0.7     0        0      0
#
#  [100 rows x 4 columns])

# %%
mood = 0.5

# Get the traits for the agents
validation_f = 'validation/'

agent1 = pd.read_csv(validation_f+'agent_1.csv')
agent2 = pd.read_csv(validation_f+'agent_2.csv')
agent3 = pd.read_csv(validation_f+'agent_3.csv')

a1_dict = agent1.to_dict()
a2_dict = agent2.to_dict()
a3_dict = agent3.to_dict()

#[pt_con, nf_ko, nf_ent, nf_is, nf_si, nf_se, mood]
a1_traits = [a1_dict['nf_ko'][0], a1_dict['nf_ent'][0], a1_dict['nf_is'][0], 
             a1_dict['nf_si'][0], a1_dict['nf_se'][0], a1_dict['pt_con'][0], mood]
a2_traits = [a2_dict['nf_ko'][0], a2_dict['nf_ent'][0], a2_dict['nf_is'][0], 
             a2_dict['nf_si'][0], a2_dict['nf_se'][0], a2_dict['pt_con'][0], mood]
a3_traits = [a3_dict['nf_ko'][0], a3_dict['nf_ent'][0], a3_dict['nf_is'][0], 
             a3_dict['nf_si'][0], a3_dict['nf_se'][0], a3_dict['pt_con'][0], mood]


# Get validation data set
data_a1 = pd.read_csv(validation_f+'validation_agent_1.csv')
data_a2 = pd.read_csv(validation_f+'validation_agent_2.csv')
data_a3 = pd.read_csv(validation_f+'validation_agent_3.csv')

messages1 = data_a1[['msg_cat_per', 'msg_cat_ent', 'msg_cat_new', 'msg_cat_edu', 
                    'msg_cat_con', 'msg_rel', 'msg_qua', 'msg_sen', 
                    'msg_sal', 'msg_med', 'msg_com', 'msg_que']]
messages2 = data_a2[['msg_cat_per', 'msg_cat_ent', 'msg_cat_new', 'msg_cat_edu', 
                    'msg_cat_con', 'msg_rel', 'msg_qua', 'msg_sen', 
                    'msg_sal', 'msg_med', 'msg_com', 'msg_que']]
messages3 = data_a3[['msg_cat_per', 'msg_cat_ent', 'msg_cat_new', 'msg_cat_edu', 
                    'msg_cat_con', 'msg_rel', 'msg_qua', 'msg_sen', 
                    'msg_sal', 'msg_med', 'msg_com', 'msg_que']]

reactions1 = data_a1[['mood', 'like', 'comment', 'share']]
reactions2 = data_a2[['mood', 'like', 'comment', 'share']]
reactions3 = data_a3[['mood', 'like', 'comment', 'share']]

# %% [markdown]
# # Agent 1

# %%
inputsDF, parameters = model.run_message_sequence(messages1.values, a1_traits,parameters, 'nb1')

# %%
parameters
# Out:
# {'arousal': [0.3, 4],
#  'attention_1': [2.8, 2],
#  'attention_2': [0.2, 2],
#  'dissatisfaction': [0.2, 2],
#  'ff_ent': [1.4, 2],
#  'ff_is': [2.1, 4],
#  'ff_ko': [1.4, 2],
#  'ff_se': [2.8, 2],
#  'ff_si': [1.4, 4],
#  'mood': [6.3, 2],
#  'mood_speed': 0.5,
#  'prep_comm': [3.5, 2],
#  'prep_like': [2.8, 2],
#  'prep_share': [2.1, 3],
#  'satisfaction': [2.8, 2],
#  'srs_sal': [0.7, 2]}

# %% [markdown]
# ## Inputs
#
# ### Message Categories

# %%
inputsDF[['msg_cat_per', 'msg_cat_ent', 'msg_cat_new', 'msg_cat_edu', 'msg_cat_con']].plot()
plt.ylabel('State')
plt.xlabel('Time step')
plt.rcParams["figure.figsize"] = (15,8)

# %% [markdown]
# ### Message characteristics

# %%
inputsDF[['msg_rel', 'msg_qua', 'msg_sen', 'msg_sal', 'msg_med', 'msg_com', 'msg_que']].plot()
plt.ylabel('State')
plt.xlabel('Time step')
plt.rcParams["figure.figsize"] = (15,8)

# %% [markdown]
# ### Sensory states

# %%
inputsDF[['srs_cat_per', 'srs_cat_ent', 'srs_cat_new', 'srs_cat_edu', 'srs_cat_con']].plot()
plt.ylabel('State')
plt.xlabel('Time step')
plt.rcParams["figure.figsize"] = (15,8)

# %% [markdown]
# ### Arousal, attention

# %%
inputsDF[['arousal', 'attention_1', 'attention_2']].plot()
plt.ylabel('State')
plt.xlabel('Time step')
plt.rcParams["figure.figsize"] = (15,8)

# %% [markdown]
# ### FFs

# %%
inputsDF[['ff_ko', 'ff_ent', 'ff_is', 'ff_si', 'ff_se']].plot()
plt.ylabel('State')
plt.xlabel('Time step')
plt.rcParams["figure.figsize"] = (15,8)

# %% [markdown]
# ### Satisfaction, dissatisfaction

# %%
inputsDF[['satisfaction', 'dissatisfaction', 'ff_se']].plot()
plt.ylabel('State')
plt.xlabel('Time step')
plt.rcParams["figure.figsize"] = (15,8)

# %% [markdown]
# ### preps and ssr's

# %%
inputsDF[['prep_like', 'ssr_pe_l', 'prep_share', 'ssr_pe_s', 'prep_comm', 'ssr_pe_c']].plot()
plt.ylabel('State')
plt.xlabel('Time step')
plt.rcParams["figure.figsize"] = (15,8)

# %% [markdown]
# ### Outputs

# %%
inputsDF[['like', 'share', 'comment']].plot()
plt.ylabel('State')
plt.xlabel('Time step')
plt.rcParams["figure.figsize"] = (15,8)

# %% [markdown]
# ### Expected reactions

# %%
reactions1[['share', 'comment', 'like']].plot()
plt.ylabel('State')
plt.xlabel('Time step')
plt.rcParams["figure.figsize"] = (15,8)

# %%
inputsDF.columns
# Out:
# Index(['arousal', 'attention_1', 'attention_2', 'comment', 'dissatisfaction',
#        'ff_ent', 'ff_is', 'ff_ko', 'ff_se', 'ff_si', 'like', 'mood',
#        'msg_cat_con', 'msg_cat_edu', 'msg_cat_ent', 'msg_cat_new',
#        'msg_cat_per', 'msg_com', 'msg_med', 'msg_qua', 'msg_que', 'msg_rel',
#        'msg_sal', 'msg_sen', 'nf_ent', 'nf_is', 'nf_ko', 'nf_se', 'nf_si',
#        'prep_comm', 'prep_like', 'prep_share', 'pt_cons', 'satisfaction',
#        'share', 'srs_cat_con', 'srs_cat_edu', 'srs_cat_ent', 'srs_cat_new',
#        'srs_cat_per', 'srs_com', 'srs_med', 'srs_qua', 'srs_que', 'srs_rel',
#        'srs_sal', 'srs_sen', 'ss_cat_con', 'ss_cat_edu', 'ss_cat_ent',
#        'ss_cat_new', 'ss_cat_per', 'ss_com', 'ss_med', 'ss_qua', 'ss_que',
#        'ss_rel', 'ss_sal', 'ss_sen', 'ssr_pe_c', 'ssr_pe_l', 'ssr_pe_s'],
#       dtype='object')

# %% [markdown]
# # Agent 2

# %%
inputsDF, parameters = model.run_message_sequence(messages1.values, a2_traits,parameters, 'nb1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0d289551ce35> in <module>()
# ----> 1 inputsDF, parameters = model.run_message_sequence(messages1.values, a2_traits,parameters, 'nb1')
#
# NameError: name 'model' is not defined

# %%
inputsDF[['msg_cat_per', 'msg_cat_ent', 'msg_cat_new', 'msg_cat_edu', 'msg_cat_con']].plot()
plt.ylabel('State')
plt.xlabel('Time step')
plt.rcParams["figure.figsize"] = (15,8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e8e4c4bece34> in <module>()
# ----> 1 inputsDF[['msg_cat_per', 'msg_cat_ent', 'msg_cat_new', 'msg_cat_edu', 'msg_cat_con']].plot()
#       2 plt.ylabel('State')
#       3 plt.xlabel('Time step')
#       4 plt.rcParams["figure.figsize"] = (15,8)
#
# NameError: name 'inputsDF' is not defined

# %%
inputsDF[['msg_rel', 'msg_qua', 'msg_sen', 'msg_sal', 'msg_med', 'msg_com', 'msg_que']].plot()
plt.ylabel('State')
plt.xlabel('Time step')
plt.rcParams["figure.figsize"] = (15,8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d711c9708c65> in <module>()
# ----> 1 inputsDF[['msg_rel', 'msg_qua', 'msg_sen', 'msg_sal', 'msg_med', 'msg_com', 'msg_que']].plot()
#       2 plt.ylabel('State')
#       3 plt.xlabel('Time step')
#       4 plt.rcParams["figure.figsize"] = (15,8)
#
# NameError: name 'inputsDF' is not defined

# %%
inputsDF[['srs_cat_per', 'srs_cat_ent', 'srs_cat_new', 'srs_cat_edu', 'srs_cat_con']].plot()
plt.ylabel('State')
plt.xlabel('Time step')
plt.rcParams["figure.figsize"] = (15,8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c99b9232e90d> in <module>()
# ----> 1 inputsDF[['srs_cat_per', 'srs_cat_ent', 'srs_cat_new', 'srs_cat_edu', 'srs_cat_con']].plot()
#       2 plt.ylabel('State')
#       3 plt.xlabel('Time step')
#       4 plt.rcParams["figure.figsize"] = (15,8)
#
# NameError: name 'inputsDF' is not defined

# %%
inputsDF[['arousal', 'attention_1', 'attention_2']].plot()
plt.ylabel('State')
plt.xlabel('Time step')
plt.rcParams["figure.figsize"] = (15,8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-8c95f549a6ca> in <module>()
# ----> 1 inputsDF[['arousal', 'attention_1', 'attention_2']].plot()
#       2 plt.ylabel('State')
#       3 plt.xlabel('Time step')
#       4 plt.rcParams["figure.figsize"] = (15,8)
#
# NameError: name 'inputsDF' is not defined

# %%
inputsDF[['ff_ko', 'ff_ent', 'ff_is', 'ff_si', 'ff_se']].plot()
plt.ylabel('State')
plt.xlabel('Time step')
plt.rcParams["figure.figsize"] = (15,8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-c67b43748de1> in <module>()
# ----> 1 inputsDF[['ff_ko', 'ff_ent', 'ff_is', 'ff_si', 'ff_se']].plot()
#       2 plt.ylabel('State')
#       3 plt.xlabel('Time step')
#       4 plt.rcParams["figure.figsize"] = (15,8)
#
# NameError: name 'inputsDF' is not defined

# %%
inputsDF[['satisfaction', 'dissatisfaction', 'ff_se']].plot()
plt.ylabel('State')
plt.xlabel('Time step')
plt.rcParams["figure.figsize"] = (15,8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-c76828708525> in <module>()
# ----> 1 inputsDF[['satisfaction', 'dissatisfaction', 'ff_se']].plot()
#       2 plt.ylabel('State')
#       3 plt.xlabel('Time step')
#       4 plt.rcParams["figure.figsize"] = (15,8)
#
# NameError: name 'inputsDF' is not defined

# %%
inputsDF[['prep_like', 'ssr_pe_l', 'prep_share', 'ssr_pe_s', 'prep_comm', 'ssr_pe_c']].plot()
plt.ylabel('State')
plt.xlabel('Time step')
plt.rcParams["figure.figsize"] = (15,8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-f29ac1267391> in <module>()
# ----> 1 inputsDF[['prep_like', 'ssr_pe_l', 'prep_share', 'ssr_pe_s', 'prep_comm', 'ssr_pe_c']].plot()
#       2 plt.ylabel('State')
#       3 plt.xlabel('Time step')
#       4 plt.rcParams["figure.figsize"] = (15,8)
#
# NameError: name 'inputsDF' is not defined

# %%
inputsDF[['like', 'share', 'comment']].plot()
plt.ylabel('State')
plt.xlabel('Time step')
plt.rcParams["figure.figsize"] = (15,8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-85c0b3d95452> in <module>()
# ----> 1 inputsDF[['like', 'share', 'comment']].plot()
#       2 plt.ylabel('State')
#       3 plt.xlabel('Time step')
#       4 plt.rcParams["figure.figsize"] = (15,8)
#
# NameError: name 'inputsDF' is not defined

# %%
reactions2[['share', 'comment', 'like']].plot()
plt.ylabel('State')
plt.xlabel('Time step')
plt.rcParams["figure.figsize"] = (15,8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-8fb6d787c044> in <module>()
# ----> 1 reactions2[['share', 'comment', 'like']].plot()
#       2 plt.ylabel('State')
#       3 plt.xlabel('Time step')
#       4 plt.rcParams["figure.figsize"] = (15,8)
#
# NameError: name 'reactions2' is not defined

# %% [markdown]
# # Agent 3

# %%
inputsDF, parameters = model.run_message_sequence(messages1.values, a3_traits,parameters, 'nb1')

# %%
inputsDF[['msg_cat_per', 'msg_cat_ent', 'msg_cat_new', 'msg_cat_edu', 'msg_cat_con']].plot()
plt.ylabel('State')
plt.xlabel('Time step')
plt.rcParams["figure.figsize"] = (15,8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e8e4c4bece34> in <module>()
# ----> 1 inputsDF[['msg_cat_per', 'msg_cat_ent', 'msg_cat_new', 'msg_cat_edu', 'msg_cat_con']].plot()
#       2 plt.ylabel('State')
#       3 plt.xlabel('Time step')
#       4 plt.rcParams["figure.figsize"] = (15,8)
#
# NameError: name 'inputsDF' is not defined

# %%
inputsDF[['msg_rel', 'msg_qua', 'msg_sen', 'msg_sal', 'msg_med', 'msg_com', 'msg_que']].plot()
plt.ylabel('State')
plt.xlabel('Time step')
plt.rcParams["figure.figsize"] = (15,8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d711c9708c65> in <module>()
# ----> 1 inputsDF[['msg_rel', 'msg_qua', 'msg_sen', 'msg_sal', 'msg_med', 'msg_com', 'msg_que']].plot()
#       2 plt.ylabel('State')
#       3 plt.xlabel('Time step')
#       4 plt.rcParams["figure.figsize"] = (15,8)
#
# NameError: name 'inputsDF' is not defined

# %%
inputsDF[['srs_cat_per', 'srs_cat_ent', 'srs_cat_new', 'srs_cat_edu', 'srs_cat_con']].plot()
plt.ylabel('State')
plt.xlabel('Time step')
plt.rcParams["figure.figsize"] = (15,8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c99b9232e90d> in <module>()
# ----> 1 inputsDF[['srs_cat_per', 'srs_cat_ent', 'srs_cat_new', 'srs_cat_edu', 'srs_cat_con']].plot()
#       2 plt.ylabel('State')
#       3 plt.xlabel('Time step')
#       4 plt.rcParams["figure.figsize"] = (15,8)
#
# NameError: name 'inputsDF' is not defined

# %%
inputsDF[['arousal', 'attention_1', 'attention_2']].plot()
plt.ylabel('State')
plt.xlabel('Time step')
plt.rcParams["figure.figsize"] = (15,8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-8c95f549a6ca> in <module>()
# ----> 1 inputsDF[['arousal', 'attention_1', 'attention_2']].plot()
#       2 plt.ylabel('State')
#       3 plt.xlabel('Time step')
#       4 plt.rcParams["figure.figsize"] = (15,8)
#
# NameError: name 'inputsDF' is not defined

# %%
inputsDF[['ff_ko', 'ff_ent', 'ff_is', 'ff_si', 'ff_se']].plot()
plt.ylabel('State')
plt.xlabel('Time step')
plt.rcParams["figure.figsize"] = (15,8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-c67b43748de1> in <module>()
# ----> 1 inputsDF[['ff_ko', 'ff_ent', 'ff_is', 'ff_si', 'ff_se']].plot()
#       2 plt.ylabel('State')
#       3 plt.xlabel('Time step')
#       4 plt.rcParams["figure.figsize"] = (15,8)
#
# NameError: name 'inputsDF' is not defined

# %%
inputsDF[['satisfaction', 'dissatisfaction', 'ff_se']].plot()
plt.ylabel('State')
plt.xlabel('Time step')
plt.rcParams["figure.figsize"] = (15,8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-c76828708525> in <module>()
# ----> 1 inputsDF[['satisfaction', 'dissatisfaction', 'ff_se']].plot()
#       2 plt.ylabel('State')
#       3 plt.xlabel('Time step')
#       4 plt.rcParams["figure.figsize"] = (15,8)
#
# NameError: name 'inputsDF' is not defined

# %%
inputsDF[['prep_like', 'ssr_pe_l', 'prep_share', 'ssr_pe_s', 'prep_comm', 'ssr_pe_c']].plot()
plt.ylabel('State')
plt.xlabel('Time step')
plt.rcParams["figure.figsize"] = (15,8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-f29ac1267391> in <module>()
# ----> 1 inputsDF[['prep_like', 'ssr_pe_l', 'prep_share', 'ssr_pe_s', 'prep_comm', 'ssr_pe_c']].plot()
#       2 plt.ylabel('State')
#       3 plt.xlabel('Time step')
#       4 plt.rcParams["figure.figsize"] = (15,8)
#
# NameError: name 'inputsDF' is not defined

# %%
inputsDF[['like', 'share', 'comment']].plot()
plt.ylabel('State')
plt.xlabel('Time step')
plt.rcParams["figure.figsize"] = (15,8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-85c0b3d95452> in <module>()
# ----> 1 inputsDF[['like', 'share', 'comment']].plot()
#       2 plt.ylabel('State')
#       3 plt.xlabel('Time step')
#       4 plt.rcParams["figure.figsize"] = (15,8)
#
# NameError: name 'inputsDF' is not defined

# %%
reactions3[['share', 'comment', 'like']].plot()
plt.ylabel('State')
plt.xlabel('Time step')
plt.rcParams["figure.figsize"] = (15,8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-8fb6d787c044> in <module>()
# ----> 1 reactions2[['share', 'comment', 'like']].plot()
#       2 plt.ylabel('State')
#       3 plt.xlabel('Time step')
#       4 plt.rcParams["figure.figsize"] = (15,8)
#
# NameError: name 'reactions2' is not defined
